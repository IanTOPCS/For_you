# %% [markdown]
# ### 將資料以指定格式讀入

# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff("../hypothyroid_modified_cjlin.arff")
data = pd.DataFrame(data[0])
data
# Out:
#        age   sex on thyroxine query on thyroxine on antithyroid medication  \
# 0     41.0  b'F'         b'f'               b'f'                      b'f'
# 1     23.0  b'F'         b'f'               b'f'                      b'f'
# 2     46.0  b'M'         b'f'               b'f'                      b'f'
# 3     70.0  b'F'         b't'               b'f'                      b'f'
# 4     70.0  b'F'         b'f'               b'f'                      b'f'
# ...    ...   ...          ...                ...                       ...
# 3393  19.0  b'F'         b'f'               b'f'                      b'f'
# 3394  68.0  b'F'         b'f'               b'f'                      b'f'
# 3395  74.0  b'F'         b'f'               b'f'                      b'f'
# 3396  72.0  b'M'         b'f'               b'f'                      b'f'
# 3397  64.0  b'F'         b'f'               b'f'                      b'f'
#
#       sick pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# 0     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 1     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 2     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 4     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# ...    ...      ...             ...            ...               ...  ...
# 3393  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3394  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3395  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3396  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3397  b'f'     b'f'            b'f'           b'f'              b'f'  ...
#
#      tumor hypopituitary psych   TSH   T3    TT4   T4U    FTI  \
# 0     b'f'          b'f'  b'f'  1.30  2.5  125.0  1.14  109.0
# 1     b'f'          b'f'  b'f'  4.10  2.0  102.0  1.00  106.0
# 2     b'f'          b'f'  b'f'  0.98  1.7  109.0  0.91  120.0
# 3     b'f'          b'f'  b'f'  0.16  1.9  175.0  1.00  106.0
# 4     b'f'          b'f'  b'f'  0.72  1.2   61.0  0.87   70.0
# ...    ...           ...   ...   ...  ...    ...   ...    ...
# 3393  b'f'          b'f'  b'f'  8.80  2.7  108.0  1.11   97.0
# 3394  b'f'          b'f'  b'f'  1.00  2.1  124.0  1.08  114.0
# 3395  b'f'          b'f'  b'f'  5.10  1.8  112.0  1.07  105.0
# 3396  b'f'          b'f'  b'f'  0.70  2.0   82.0  0.94   87.0
# 3397  b'f'          b'f'  b'f'  1.00  2.2   99.0  1.07   92.0
#
#       referral source                       Class
# 0             b'SVHC'                 b'negative'
# 1            b'other'                 b'negative'
# 2            b'other'                 b'negative'
# 3            b'other'                 b'negative'
# 4              b'SVI'                 b'negative'
# ...               ...                         ...
# 3393         b'other'  b'compensated_hypothyroid'
# 3394           b'SVI'                 b'negative'
# 3395         b'other'                 b'negative'
# 3396           b'SVI'                 b'negative'
# 3397         b'other'                 b'negative'
#
# [3398 rows x 23 columns]

# %% [markdown]
# ### 將資料以指定格式讀入

# %%
import matplotlib.pyplot as plt
ansType = {cls: 0 for cls in set(data["Class"])}
total = 0
for cls in data["Class"]:
    ansType[cls] += 1
    total += 1
    
# 將字串百分比轉成數值以便畫圖
labels = [key.decode() if isinstance(key, bytes) else str(key) for key in ansType.keys()]
values = [float(val) for val in ansType.values()]

# 畫出圓餅圖
plt.figure(figsize=(10, 5))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Class Distribution")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 資料轉成one-hot-encoding，切分資料(4:1)

# %%
from sklearn.model_selection import train_test_split

# one-hot-encoding
data = pd.get_dummies(data)

# x is features of result, y represent result collection
x = data.iloc[:,0:-4]
y = data.iloc[:,-4:]
# x, y _train are data used to training, x, y _test are used to test training of ML result
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2, random_state=42)
x_train = x_train.to_numpy()
y_train = y_train.to_numpy()
x_test = x_test.to_numpy()
y_test = y_test.to_numpy()

data
# Out:
#        age   TSH   T3    TT4   T4U    FTI  sex_b'F'  sex_b'M'  \
# 0     41.0  1.30  2.5  125.0  1.14  109.0      True     False
# 1     23.0  4.10  2.0  102.0  1.00  106.0      True     False
# 2     46.0  0.98  1.7  109.0  0.91  120.0     False      True
# 3     70.0  0.16  1.9  175.0  1.00  106.0      True     False
# 4     70.0  0.72  1.2   61.0  0.87   70.0      True     False
# ...    ...   ...  ...    ...   ...    ...       ...       ...
# 3393  19.0  8.80  2.7  108.0  1.11   97.0      True     False
# 3394  68.0  1.00  2.1  124.0  1.08  114.0      True     False
# 3395  74.0  5.10  1.8  112.0  1.07  105.0      True     False
# 3396  72.0  0.70  2.0   82.0  0.94   87.0     False      True
# 3397  64.0  1.00  2.2   99.0  1.07   92.0      True     False
#
#       on thyroxine_b'f'  on thyroxine_b't'  ...  psych_b't'  \
# 0                  True              False  ...       False
# 1                  True              False  ...       False
# 2                  True              False  ...       False
# 3                 False               True  ...       False
# 4                  True              False  ...       False
# ...                 ...                ...  ...         ...
# 3393               True              False  ...       False
# 3394               True              False  ...       False
# 3395               True              False  ...       False
# 3396               True              False  ...       False
# 3397               True              False  ...       False
#
#       referral source_b'STMW'  referral source_b'SVHC'  \
# 0                       False                     True
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 3393                    False                    False
# 3394                    False                    False
# 3395                    False                    False
# 3396                    False                    False
# 3397                    False                    False
#
#       referral source_b'SVHD'  referral source_b'SVI'  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                    True
# ...                       ...                     ...
# 3393                    False                   False
# 3394                    False                    True
# 3395                    False                   False
# 3396                    False                    True
# 3397                    False                   False
#
#       referral source_b'other'  Class_b'compensated_hypothyroid'  \
# 0                        False                             False
# 1                         True                             False
# 2                         True                             False
# 3                         True                             False
# 4                        False                             False
# ...                        ...                               ...
# 3393                      True                              True
# 3394                     False                             False
# 3395                      True                             False
# 3396                     False                             False
# 3397                      True                             False
#
#       Class_b'negative'  Class_b'primary_hypothyroid'  \
# 0                  True                         False
# 1                  True                         False
# 2                  True                         False
# 3                  True                         False
# 4                  True                         False
# ...                 ...                           ...
# 3393              False                         False
# 3394               True                         False
# 3395               True                         False
# 3396               True                         False
# 3397               True                         False
#
#       Class_b'secondary_hypothyroid'
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 3393                           False
# 3394                           False
# 3395                           False
# 3396                           False
# 3397                           False
#
# [3398 rows x 45 columns]

# %% [markdown]
# ### 建立 Transformer model

# %%
import tensorflow as tf
from tensorflow.keras import layers

# 定義 Transformer Encoder Block
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)

        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# 建立模型
input_layer = layers.Input(shape=(41, 1)) # 41 characters

# 線性升維（將原本的特徵轉成可處理的 embedding 向量）
x = layers.Dense(64)(input_layer)

# 加入 Transformer Block
x = TransformerEncoder(embed_dim=64, num_heads=4, ff_dim=128)(x)
x = layers.Dropout(0.3)(x)

# 聚合整體序列資訊
x = layers.GlobalAveragePooling1D()(x)

x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
output_layer = layers.Dense(4, activation='softmax')(x)

model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 41, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 41, 64)         │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_encoder_2           │ (None, 41, 64)         │        83,200 │
# │ (TransformerEncoder)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 41, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 87,748 (342.77 KB)
#  Trainable params: 87,748 (342.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Using 0.001 as learning rate
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss=tf.losses.CategoricalCrossentropy(from_logits=True),
              metrics=[tf.metrics.CategoricalAccuracy(name='accuracy')])

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
# If "loss" consecutive till 10 time, stop to avoid overfitting
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


x_train1 = np.asarray(x_train, dtype=K.floatx())
y_train1 = np.asarray(y_train, dtype=K.floatx())
x_test1  = np.asarray(x_test,  dtype=K.floatx())
y_test1  = np.asarray(y_test,  dtype=K.floatx())

# To fit CNN model, change dimention of data
x_train1 = x_train1.reshape((-1, 41, 1))
x_test1 = x_test1.reshape((-1, 41, 1))

# epochs=400：最多訓練 400 個 epoch
# batch_size=20：每次訓練用 20 筆資料計算一次梯度更新
# validation_data：指定測試集作為驗證資料，用來評估每一輪的效能
# verbose=1：每個 epoch 顯示訓練進度條與評估指標
# callbacks=[earlyStopping]：若 loss 沒改善，會自動中止訓練以避免過度訓練
history = model.fit(
    x_train1,
    y_train1,
    epochs=400,
    batch_size=20,
    validation_data=(x_test1, y_test1),
    verbose=1,
    callbacks=[earlyStopping]
)
# Out:
# Epoch 1/400
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:666: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8620 - loss: 0.5183 - val_accuracy: 0.9382 - val_loss: 0.2600
# Epoch 2/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9077 - loss: 0.4080 - val_accuracy: 0.9382 - val_loss: 0.2257
# Epoch 3/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9133 - loss: 0.3416 - val_accuracy: 0.9426 - val_loss: 0.2443
# Epoch 4/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9205 - loss: 0.2720 - val_accuracy: 0.9382 - val_loss: 0.2395
# Epoch 5/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9079 - loss: 0.2996 - val_accuracy: 0.9397 - val_loss: 0.1798
# Epoch 6/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9059 - loss: 0.2715 - val_accuracy: 0.9441 - val_loss: 0.1693
# Epoch 7/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9267 - loss: 0.2426 - val_accuracy: 0.9412 - val_loss: 0.1923
# Epoch 8/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9163 - loss: 0.2601 - val_accuracy: 0.9426 - val_loss: 0.1680
# Epoch 9/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9222 - loss: 0.2427 - val_accuracy: 0.9382 - val_loss: 0.2105
# Epoch 10/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9301 - loss: 0.2234 - val_accuracy: 0.9471 - val_loss: 0.1661
# Epoch 11/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9297 - loss: 0.2235 - val_accuracy: 0.9382 - val_loss: 0.2377
# Epoch 12/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9193 - loss: 0.2465 - val_accuracy: 0.9309 - val_loss: 0.2116
# Epoch 13/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9164 - loss: 0.2542 - val_accuracy: 0.9471 - val_loss: 0.1889
# Epoch 14/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9192 - loss: 0.2257 - val_accuracy: 0.9456 - val_loss: 0.1650
# Epoch 15/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9237 - loss: 0.2325 - val_accuracy: 0.9456 - val_loss: 0.1646
# Epoch 16/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ -1s -9651us/step - accuracy: 0.9271 - loss: 0.2155 - val_accuracy: 0.9441 - val_loss: 0.1667
# Epoch 17/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9274 - loss: 0.2248 - val_accuracy: 0.9471 - val_loss: 0.1598
# Epoch 18/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9310 - loss: 0.2079 - val_accuracy: 0.9426 - val_loss: 0.1685
# Epoch 19/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9177 - loss: 0.2414 - val_accuracy: 0.9456 - val_loss: 0.1630
# Epoch 20/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9214 - loss: 0.2345 - val_accuracy: 0.9456 - val_loss: 0.1626
# Epoch 21/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9207 - loss: 0.2070 - val_accuracy: 0.9426 - val_loss: 0.1686
# Epoch 22/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9255 - loss: 0.2235 - val_accuracy: 0.9412 - val_loss: 0.1807
# Epoch 23/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9249 - loss: 0.2123 - val_accuracy: 0.9382 - val_loss: 0.1926
# Epoch 24/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9226 - loss: 0.2329 - val_accuracy: 0.9471 - val_loss: 0.1663
# Epoch 25/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9217 - loss: 0.2286 - val_accuracy: 0.9426 - val_loss: 0.1657
# Epoch 26/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9285 - loss: 0.2161 - val_accuracy: 0.9426 - val_loss: 0.1490
# Epoch 27/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9264 - loss: 0.1985 - val_accuracy: 0.9515 - val_loss: 0.1610
# Epoch 28/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9308 - loss: 0.2198 - val_accuracy: 0.9456 - val_loss: 0.1635
# Epoch 29/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9231 - loss: 0.2277 - val_accuracy: 0.9485 - val_loss: 0.1725
# Epoch 30/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9279 - loss: 0.2149 - val_accuracy: 0.9441 - val_loss: 0.1408
# Epoch 31/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9389 - loss: 0.1788 - val_accuracy: 0.9426 - val_loss: 0.1485
# Epoch 32/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9302 - loss: 0.1895 - val_accuracy: 0.9456 - val_loss: 0.1381
# Epoch 33/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9320 - loss: 0.1992 - val_accuracy: 0.9397 - val_loss: 0.1500
# Epoch 34/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9354 - loss: 0.1770 - val_accuracy: 0.9500 - val_loss: 0.1293
# Epoch 35/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9367 - loss: 0.1587 - val_accuracy: 0.9471 - val_loss: 0.1424
# Epoch 36/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ -1s -6619us/step - accuracy: 0.9213 - loss: 0.2077 - val_accuracy: 0.9574 - val_loss: 0.1326
# Epoch 37/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9328 - loss: 0.1782 - val_accuracy: 0.9412 - val_loss: 0.1368
# Epoch 38/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9319 - loss: 0.1935 - val_accuracy: 0.9588 - val_loss: 0.1263
# Epoch 39/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9377 - loss: 0.1801 - val_accuracy: 0.9603 - val_loss: 0.1258
# Epoch 40/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9464 - loss: 0.1538 - val_accuracy: 0.9515 - val_loss: 0.1204
# Epoch 41/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9381 - loss: 0.1606 - val_accuracy: 0.9397 - val_loss: 0.1716
# Epoch 42/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9378 - loss: 0.1710 - val_accuracy: 0.9618 - val_loss: 0.1109
# Epoch 43/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9402 - loss: 0.1652 - val_accuracy: 0.9456 - val_loss: 0.1333
# Epoch 44/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9440 - loss: 0.1690 - val_accuracy: 0.9618 - val_loss: 0.1219
# Epoch 45/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9436 - loss: 0.1601 - val_accuracy: 0.9500 - val_loss: 0.1311
# Epoch 46/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9398 - loss: 0.1655 - val_accuracy: 0.9662 - val_loss: 0.1137
# Epoch 47/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9396 - loss: 0.1517 - val_accuracy: 0.9515 - val_loss: 0.1229
# Epoch 48/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9370 - loss: 0.1627 - val_accuracy: 0.9441 - val_loss: 0.1260
# Epoch 49/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9387 - loss: 0.1669 - val_accuracy: 0.9544 - val_loss: 0.1022
# Epoch 50/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9404 - loss: 0.1607 - val_accuracy: 0.9588 - val_loss: 0.1040
# Epoch 51/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9431 - loss: 0.1458 - val_accuracy: 0.9500 - val_loss: 0.1452
# Epoch 52/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9316 - loss: 0.1560 - val_accuracy: 0.9632 - val_loss: 0.1055
# Epoch 53/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9455 - loss: 0.1542 - val_accuracy: 0.9603 - val_loss: 0.0965
# Epoch 54/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9389 - loss: 0.1742 - val_accuracy: 0.9426 - val_loss: 0.1499
# Epoch 55/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ -1s -9660us/step - accuracy: 0.9361 - loss: 0.1627 - val_accuracy: 0.9662 - val_loss: 0.1004
# Epoch 56/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9535 - loss: 0.1208 - val_accuracy: 0.9632 - val_loss: 0.1040
# Epoch 57/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9487 - loss: 0.1322 - val_accuracy: 0.9618 - val_loss: 0.0959
# Epoch 58/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9435 - loss: 0.1543 - val_accuracy: 0.9529 - val_loss: 0.1240
# Epoch 59/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9523 - loss: 0.1189 - val_accuracy: 0.9559 - val_loss: 0.0954
# Epoch 60/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9342 - loss: 0.1645 - val_accuracy: 0.9647 - val_loss: 0.1153
# Epoch 61/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9472 - loss: 0.1539 - val_accuracy: 0.9559 - val_loss: 0.1034
# Epoch 62/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9502 - loss: 0.1384 - val_accuracy: 0.9485 - val_loss: 0.1101
# Epoch 63/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9517 - loss: 0.1239 - val_accuracy: 0.9588 - val_loss: 0.1144
# Epoch 64/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9502 - loss: 0.1349 - val_accuracy: 0.9529 - val_loss: 0.1291
# Epoch 65/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9460 - loss: 0.1477 - val_accuracy: 0.9588 - val_loss: 0.0976
# Epoch 66/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9551 - loss: 0.1197 - val_accuracy: 0.9588 - val_loss: 0.1453
# Epoch 67/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9469 - loss: 0.1751 - val_accuracy: 0.9559 - val_loss: 0.1332
# Epoch 68/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9428 - loss: 0.1887 - val_accuracy: 0.9529 - val_loss: 0.1356
# Epoch 69/400
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9389 - loss: 0.1899 - val_accuracy: 0.9559 - val_loss: 0.1136

# %%
history_dict = history.history
acc = history_dict['accuracy']         # 訓練集準確率
val_acc = history_dict['val_accuracy'] # 驗證集準確率
loss = history_dict['loss']            # 訓練集損失
val_loss = history_dict['val_loss']    # 驗證集損失
epochs = range(1, len(acc) + 1)

# %%
import matplotlib.pyplot as plt
plt.plot(epochs, loss, 'r', label='Training loss')

plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf() # clean current figure
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.evaluate(x_test1, y_test1)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1083
# [0.0954483225941658, 0.9558823704719543]
