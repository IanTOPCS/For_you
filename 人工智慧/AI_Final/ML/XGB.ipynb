# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff("../hypothyroid_modified_cjlin.arff")
data = pd.DataFrame(data[0])
data
# Out:
#        age   sex on thyroxine query on thyroxine on antithyroid medication  \
# 0     41.0  b'F'         b'f'               b'f'                      b'f'
# 1     23.0  b'F'         b'f'               b'f'                      b'f'
# 2     46.0  b'M'         b'f'               b'f'                      b'f'
# 3     70.0  b'F'         b't'               b'f'                      b'f'
# 4     70.0  b'F'         b'f'               b'f'                      b'f'
# ...    ...   ...          ...                ...                       ...
# 3393  19.0  b'F'         b'f'               b'f'                      b'f'
# 3394  68.0  b'F'         b'f'               b'f'                      b'f'
# 3395  74.0  b'F'         b'f'               b'f'                      b'f'
# 3396  72.0  b'M'         b'f'               b'f'                      b'f'
# 3397  64.0  b'F'         b'f'               b'f'                      b'f'
#
#       sick pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# 0     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 1     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 2     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 4     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# ...    ...      ...             ...            ...               ...  ...
# 3393  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3394  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3395  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3396  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3397  b'f'     b'f'            b'f'           b'f'              b'f'  ...
#
#      tumor hypopituitary psych   TSH   T3    TT4   T4U    FTI  \
# 0     b'f'          b'f'  b'f'  1.30  2.5  125.0  1.14  109.0
# 1     b'f'          b'f'  b'f'  4.10  2.0  102.0  1.00  106.0
# 2     b'f'          b'f'  b'f'  0.98  1.7  109.0  0.91  120.0
# 3     b'f'          b'f'  b'f'  0.16  1.9  175.0  1.00  106.0
# 4     b'f'          b'f'  b'f'  0.72  1.2   61.0  0.87   70.0
# ...    ...           ...   ...   ...  ...    ...   ...    ...
# 3393  b'f'          b'f'  b'f'  8.80  2.7  108.0  1.11   97.0
# 3394  b'f'          b'f'  b'f'  1.00  2.1  124.0  1.08  114.0
# 3395  b'f'          b'f'  b'f'  5.10  1.8  112.0  1.07  105.0
# 3396  b'f'          b'f'  b'f'  0.70  2.0   82.0  0.94   87.0
# 3397  b'f'          b'f'  b'f'  1.00  2.2   99.0  1.07   92.0
#
#       referral source                       Class
# 0             b'SVHC'                 b'negative'
# 1            b'other'                 b'negative'
# 2            b'other'                 b'negative'
# 3            b'other'                 b'negative'
# 4              b'SVI'                 b'negative'
# ...               ...                         ...
# 3393         b'other'  b'compensated_hypothyroid'
# 3394           b'SVI'                 b'negative'
# 3395         b'other'                 b'negative'
# 3396           b'SVI'                 b'negative'
# 3397         b'other'                 b'negative'
#
# [3398 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
ansType = {cls: 0 for cls in set(data["Class"])}
total = 0
for cls in data["Class"]:
    ansType[cls] += 1
    total += 1
    
# 將字串百分比轉成數值以便畫圖
labels = [key.decode() if isinstance(key, bytes) else str(key) for key in ansType.keys()]
values = [float(val) for val in ansType.values()]

# 畫出圓餅圖
plt.figure(figsize=(10, 5))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Class Distribution")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
data = pd.get_dummies(data)

x = data.iloc[:,0:-4]
y = data.iloc[:,-4:]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train = x_train.to_numpy()
y_train = y_train.to_numpy()
x_test = x_test.to_numpy()
y_test = y_test.to_numpy()

# 將 one-hot 轉回類別標籤以便 sklearn 相容
y_train_cls = np.argmax(y_train, axis=1)
y_test_cls = np.argmax(y_test, axis=1)

data
# Out:
#        age   TSH   T3    TT4   T4U    FTI  sex_b'F'  sex_b'M'  \
# 0     41.0  1.30  2.5  125.0  1.14  109.0      True     False
# 1     23.0  4.10  2.0  102.0  1.00  106.0      True     False
# 2     46.0  0.98  1.7  109.0  0.91  120.0     False      True
# 3     70.0  0.16  1.9  175.0  1.00  106.0      True     False
# 4     70.0  0.72  1.2   61.0  0.87   70.0      True     False
# ...    ...   ...  ...    ...   ...    ...       ...       ...
# 3393  19.0  8.80  2.7  108.0  1.11   97.0      True     False
# 3394  68.0  1.00  2.1  124.0  1.08  114.0      True     False
# 3395  74.0  5.10  1.8  112.0  1.07  105.0      True     False
# 3396  72.0  0.70  2.0   82.0  0.94   87.0     False      True
# 3397  64.0  1.00  2.2   99.0  1.07   92.0      True     False
#
#       on thyroxine_b'f'  on thyroxine_b't'  ...  psych_b't'  \
# 0                  True              False  ...       False
# 1                  True              False  ...       False
# 2                  True              False  ...       False
# 3                 False               True  ...       False
# 4                  True              False  ...       False
# ...                 ...                ...  ...         ...
# 3393               True              False  ...       False
# 3394               True              False  ...       False
# 3395               True              False  ...       False
# 3396               True              False  ...       False
# 3397               True              False  ...       False
#
#       referral source_b'STMW'  referral source_b'SVHC'  \
# 0                       False                     True
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 3393                    False                    False
# 3394                    False                    False
# 3395                    False                    False
# 3396                    False                    False
# 3397                    False                    False
#
#       referral source_b'SVHD'  referral source_b'SVI'  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                    True
# ...                       ...                     ...
# 3393                    False                   False
# 3394                    False                    True
# 3395                    False                   False
# 3396                    False                    True
# 3397                    False                   False
#
#       referral source_b'other'  Class_b'compensated_hypothyroid'  \
# 0                        False                             False
# 1                         True                             False
# 2                         True                             False
# 3                         True                             False
# 4                        False                             False
# ...                        ...                               ...
# 3393                      True                              True
# 3394                     False                             False
# 3395                      True                             False
# 3396                     False                             False
# 3397                      True                             False
#
#       Class_b'negative'  Class_b'primary_hypothyroid'  \
# 0                  True                         False
# 1                  True                         False
# 2                  True                         False
# 3                  True                         False
# 4                  True                         False
# ...                 ...                           ...
# 3393              False                         False
# 3394               True                         False
# 3395               True                         False
# 3396               True                         False
# 3397               True                         False
#
#       Class_b'secondary_hypothyroid'
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 3393                           False
# 3394                           False
# 3395                           False
# 3396                           False
# 3397                           False
#
# [3398 rows x 45 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_bar_metrics(acc_list, f1_list, loss_list, model_name="Model"):
    runs = np.arange(1, len(acc_list) + 1)

    # 畫圖
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.bar(runs, acc_list, color='skyblue')
    plt.title(f"{model_name} - Accuracy per Run")
    plt.xlabel("Run")
    plt.ylabel("Accuracy")
    plt.ylim(0, 1)

    plt.subplot(1, 3, 2)
    plt.bar(runs, loss_list, color='salmon')
    plt.title(f"{model_name} - Log Loss per Run")
    plt.xlabel("Run")
    plt.ylabel("Loss")

    plt.subplot(1, 3, 3)
    plt.bar(runs, f1_list, color='lightgreen')
    plt.title(f"{model_name} - F1 Score per Run")
    plt.xlabel("Run")
    plt.ylabel("F1 Macro")
    plt.ylim(0, 1)

    plt.tight_layout()
    plt.show()

    # 整理成表格
    df = pd.DataFrame({
        "Run": runs,
        "Accuracy": np.round(acc_list, 4),
        "Log Loss": np.round(loss_list, 4),
        "F1 Macro": np.round(f1_list, 4)
    })

    print(f"\n {model_name} - Detailed Results:")
    print(df.to_string(index=False))

    # 清除避免污染
    acc_list.clear()
    f1_list.clear()
    loss_list.clear()

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, log_loss
import numpy as np
import pandas as pd

# 儲存結果
acc_list, f1_list, loss_list = [], [], []
results_grid = []

# 所有類別，避免 log_loss 出錯
all_labels = list(np.unique(np.concatenate([y_train_cls, y_test_cls])))

# 超參數設定
param_grid_xgb = {
    'clf__n_estimators': [50, 100],
    'clf__learning_rate': [0.05, 0.1],
    'clf__max_depth': [3, 5]
}

for run in range(10):
    print(f"\nRun {run+1}")

    pipe = Pipeline([
        ('clf', XGBClassifier(use_label_encoder=False, eval_metric='mlogloss'))
    ])

    grid = GridSearchCV(pipe, param_grid_xgb, cv=5, scoring='accuracy', n_jobs=-1)
    grid.fit(x_train, y_train_cls)

    best_model = grid.best_estimator_
    y_pred = best_model.predict(x_test)
    y_prob = best_model.predict_proba(x_test)

    acc = accuracy_score(y_test_cls, y_pred)
    f1 = f1_score(y_test_cls, y_pred, average='macro')
    loss = log_loss(y_test_cls, y_prob, labels=all_labels)

    acc_list.append(acc)
    f1_list.append(f1)
    loss_list.append(loss)

    # 記錄所有組合
    for i in range(len(grid.cv_results_['params'])):
        params = grid.cv_results_['params'][i]
        clf = XGBClassifier(
            n_estimators=params['clf__n_estimators'],
            learning_rate=params['clf__learning_rate'],
            max_depth=params['clf__max_depth'],
            use_label_encoder=False,
            eval_metric='mlogloss'
        )
        clf.fit(x_train, y_train_cls)
        y_pred_i = clf.predict(x_test)
        y_prob_i = clf.predict_proba(x_test)
        acc_i = accuracy_score(y_test_cls, y_pred_i)
        f1_i = f1_score(y_test_cls, y_pred_i, average='macro')
        loss_i = log_loss(y_test_cls, y_prob_i, labels=all_labels)

        results_grid.append({
            'n_estimators': params['clf__n_estimators'],
            'learning_rate': params['clf__learning_rate'],
            'max_depth': params['clf__max_depth'],
            'acc': acc_i,
            'loss': loss_i,
            'f1': f1_i
        })
# Out:
# Run 1
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:37] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Run 2
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Run 3
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:45] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:45] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Run 4
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:48] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:50] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Run 5
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:09:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:07] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:09] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:09] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:09] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:09] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Run 10
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/devuser/.local/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [14:10:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
df_results = pd.DataFrame(results_grid)
print("\n 所有參數組合結果：")
print(df_results.sort_values(by='acc', ascending=False).reset_index(drop=True))
# Out:
#  所有參數組合結果：
#     n_estimators  learning_rate  max_depth       acc      loss        f1
# 0             50           0.10          5  0.997059  0.021012  0.982436
# 1            100           0.10          5  0.997059  0.012950  0.982436
# 2            100           0.10          5  0.997059  0.012950  0.982436
# 3             50           0.10          5  0.997059  0.021012  0.982436
# 4             50           0.10          5  0.997059  0.021012  0.982436
# ..           ...            ...        ...       ...       ...       ...
# 75           100           0.05          3  0.991176  0.024636  0.940401
# 76           100           0.05          3  0.991176  0.024636  0.940401
# 77            50           0.05          3  0.991176  0.106475  0.941219
# 78            50           0.05          3  0.991176  0.106475  0.941219
# 79           100           0.05          3  0.991176  0.024636  0.940401
#
# [80 rows x 6 columns]

# %%
best_acc_row = df_results.loc[df_results['acc'].idxmax()]
best_loss_row = df_results.loc[df_results['loss'].idxmin()]
best_f1_row = df_results.loc[df_results['f1'].idxmax()]

print("\n 最佳 Accuracy 組合：")
print(best_acc_row.to_frame().T)

print("\n 最低 Loss 組合：")
print(best_loss_row.to_frame().T)

print("\n 最高 F1 Score 組合：")
print(best_f1_row.to_frame().T)
# Out:
#  最佳 Accuracy 組合：
#    n_estimators  learning_rate  max_depth       acc      loss        f1
# 6          50.0            0.1        5.0  0.997059  0.021012  0.982436
#
#  最低 Loss 組合：
#    n_estimators  learning_rate  max_depth       acc     loss        f1
# 7         100.0            0.1        5.0  0.997059  0.01295  0.982436
#
#  最高 F1 Score 組合：
#    n_estimators  learning_rate  max_depth       acc      loss        f1
# 6          50.0            0.1        5.0  0.997059  0.021012  0.982436

# %%
plot_bar_metrics(acc_list, f1_list, loss_list, model_name="XGB")
# Out:
#  XGB - Detailed Results:
#  Run  Accuracy  Log Loss  F1 Macro
#    1    0.9941     0.015    0.9524
#    2    0.9941     0.015    0.9524
#    3    0.9941     0.015    0.9524
#    4    0.9941     0.015    0.9524
#    5    0.9941     0.015    0.9524
#    6    0.9941     0.015    0.9524
#    7    0.9941     0.015    0.9524
#    8    0.9941     0.015    0.9524
#    9    0.9941     0.015    0.9524
#   10    0.9941     0.015    0.9524
