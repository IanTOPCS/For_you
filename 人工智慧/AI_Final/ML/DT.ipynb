# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff("../hypothyroid_modified_cjlin.arff")
data = pd.DataFrame(data[0])
data
# Out:
#        age   sex on thyroxine query on thyroxine on antithyroid medication  \
# 0     41.0  b'F'         b'f'               b'f'                      b'f'
# 1     23.0  b'F'         b'f'               b'f'                      b'f'
# 2     46.0  b'M'         b'f'               b'f'                      b'f'
# 3     70.0  b'F'         b't'               b'f'                      b'f'
# 4     70.0  b'F'         b'f'               b'f'                      b'f'
# ...    ...   ...          ...                ...                       ...
# 3393  19.0  b'F'         b'f'               b'f'                      b'f'
# 3394  68.0  b'F'         b'f'               b'f'                      b'f'
# 3395  74.0  b'F'         b'f'               b'f'                      b'f'
# 3396  72.0  b'M'         b'f'               b'f'                      b'f'
# 3397  64.0  b'F'         b'f'               b'f'                      b'f'
#
#       sick pregnant thyroid surgery I131 treatment query hypothyroid  ...  \
# 0     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 1     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 2     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 4     b'f'     b'f'            b'f'           b'f'              b'f'  ...
# ...    ...      ...             ...            ...               ...  ...
# 3393  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3394  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3395  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3396  b'f'     b'f'            b'f'           b'f'              b'f'  ...
# 3397  b'f'     b'f'            b'f'           b'f'              b'f'  ...
#
#      tumor hypopituitary psych   TSH   T3    TT4   T4U    FTI  \
# 0     b'f'          b'f'  b'f'  1.30  2.5  125.0  1.14  109.0
# 1     b'f'          b'f'  b'f'  4.10  2.0  102.0  1.00  106.0
# 2     b'f'          b'f'  b'f'  0.98  1.7  109.0  0.91  120.0
# 3     b'f'          b'f'  b'f'  0.16  1.9  175.0  1.00  106.0
# 4     b'f'          b'f'  b'f'  0.72  1.2   61.0  0.87   70.0
# ...    ...           ...   ...   ...  ...    ...   ...    ...
# 3393  b'f'          b'f'  b'f'  8.80  2.7  108.0  1.11   97.0
# 3394  b'f'          b'f'  b'f'  1.00  2.1  124.0  1.08  114.0
# 3395  b'f'          b'f'  b'f'  5.10  1.8  112.0  1.07  105.0
# 3396  b'f'          b'f'  b'f'  0.70  2.0   82.0  0.94   87.0
# 3397  b'f'          b'f'  b'f'  1.00  2.2   99.0  1.07   92.0
#
#       referral source                       Class
# 0             b'SVHC'                 b'negative'
# 1            b'other'                 b'negative'
# 2            b'other'                 b'negative'
# 3            b'other'                 b'negative'
# 4              b'SVI'                 b'negative'
# ...               ...                         ...
# 3393         b'other'  b'compensated_hypothyroid'
# 3394           b'SVI'                 b'negative'
# 3395         b'other'                 b'negative'
# 3396           b'SVI'                 b'negative'
# 3397         b'other'                 b'negative'
#
# [3398 rows x 23 columns]

# %%
import matplotlib.pyplot as plt
ansType = {cls: 0 for cls in set(data["Class"])}
total = 0
for cls in data["Class"]:
    ansType[cls] += 1
    total += 1
    
# 將字串百分比轉成數值以便畫圖
labels = [key.decode() if isinstance(key, bytes) else str(key) for key in ansType.keys()]
values = [float(val) for val in ansType.values()]

# 畫出圓餅圖
plt.figure(figsize=(10, 5))
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Class Distribution")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
data = pd.get_dummies(data)

x = data.iloc[:,0:-4]
y = data.iloc[:,-4:]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train = x_train.to_numpy()
y_train = y_train.to_numpy()
x_test = x_test.to_numpy()
y_test = y_test.to_numpy()

# 將 one-hot 轉回類別標籤以便 sklearn 相容
y_train_cls = np.argmax(y_train, axis=1)
y_test_cls = np.argmax(y_test, axis=1)

data
# Out:
#        age   TSH   T3    TT4   T4U    FTI  sex_b'F'  sex_b'M'  \
# 0     41.0  1.30  2.5  125.0  1.14  109.0      True     False
# 1     23.0  4.10  2.0  102.0  1.00  106.0      True     False
# 2     46.0  0.98  1.7  109.0  0.91  120.0     False      True
# 3     70.0  0.16  1.9  175.0  1.00  106.0      True     False
# 4     70.0  0.72  1.2   61.0  0.87   70.0      True     False
# ...    ...   ...  ...    ...   ...    ...       ...       ...
# 3393  19.0  8.80  2.7  108.0  1.11   97.0      True     False
# 3394  68.0  1.00  2.1  124.0  1.08  114.0      True     False
# 3395  74.0  5.10  1.8  112.0  1.07  105.0      True     False
# 3396  72.0  0.70  2.0   82.0  0.94   87.0     False      True
# 3397  64.0  1.00  2.2   99.0  1.07   92.0      True     False
#
#       on thyroxine_b'f'  on thyroxine_b't'  ...  psych_b't'  \
# 0                  True              False  ...       False
# 1                  True              False  ...       False
# 2                  True              False  ...       False
# 3                 False               True  ...       False
# 4                  True              False  ...       False
# ...                 ...                ...  ...         ...
# 3393               True              False  ...       False
# 3394               True              False  ...       False
# 3395               True              False  ...       False
# 3396               True              False  ...       False
# 3397               True              False  ...       False
#
#       referral source_b'STMW'  referral source_b'SVHC'  \
# 0                       False                     True
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ...                       ...                      ...
# 3393                    False                    False
# 3394                    False                    False
# 3395                    False                    False
# 3396                    False                    False
# 3397                    False                    False
#
#       referral source_b'SVHD'  referral source_b'SVI'  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                    True
# ...                       ...                     ...
# 3393                    False                   False
# 3394                    False                    True
# 3395                    False                   False
# 3396                    False                    True
# 3397                    False                   False
#
#       referral source_b'other'  Class_b'compensated_hypothyroid'  \
# 0                        False                             False
# 1                         True                             False
# 2                         True                             False
# 3                         True                             False
# 4                        False                             False
# ...                        ...                               ...
# 3393                      True                              True
# 3394                     False                             False
# 3395                      True                             False
# 3396                     False                             False
# 3397                      True                             False
#
#       Class_b'negative'  Class_b'primary_hypothyroid'  \
# 0                  True                         False
# 1                  True                         False
# 2                  True                         False
# 3                  True                         False
# 4                  True                         False
# ...                 ...                           ...
# 3393              False                         False
# 3394               True                         False
# 3395               True                         False
# 3396               True                         False
# 3397               True                         False
#
#       Class_b'secondary_hypothyroid'
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 3393                           False
# 3394                           False
# 3395                           False
# 3396                           False
# 3397                           False
#
# [3398 rows x 45 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_bar_metrics(acc_list, f1_list, loss_list, model_name="Model"):
    runs = np.arange(1, len(acc_list) + 1)

    # 畫圖
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.bar(runs, acc_list, color='skyblue')
    plt.title(f"{model_name} - Accuracy per Run")
    plt.xlabel("Run")
    plt.ylabel("Accuracy")
    plt.ylim(0, 1)

    plt.subplot(1, 3, 2)
    plt.bar(runs, loss_list, color='salmon')
    plt.title(f"{model_name} - Log Loss per Run")
    plt.xlabel("Run")
    plt.ylabel("Loss")

    plt.subplot(1, 3, 3)
    plt.bar(runs, f1_list, color='lightgreen')
    plt.title(f"{model_name} - F1 Score per Run")
    plt.xlabel("Run")
    plt.ylabel("F1 Macro")
    plt.ylim(0, 1)

    plt.tight_layout()
    plt.show()

    # 整理成表格
    df = pd.DataFrame({
        "Run": runs,
        "Accuracy": np.round(acc_list, 4),
        "Log Loss": np.round(loss_list, 4),
        "F1 Macro": np.round(f1_list, 4)
    })

    print(f"\n {model_name} - Detailed Results:")
    print(df.to_string(index=False))

    # 清除避免污染
    acc_list.clear()
    f1_list.clear()
    loss_list.clear()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, log_loss
from sklearn.utils.multiclass import unique_labels

pipe = Pipeline([
    ('clf', DecisionTreeClassifier())
])

acc_list = []
f1_list = []
loss_list = []
results_grid = []

param_grid_dt = {
    'clf__max_depth': [3, 5, 10, None],
    'clf__min_samples_split': [2, 5, 10],
    'clf__min_samples_leaf': [1, 2, 4],
    'clf__criterion': ['gini', 'entropy']
}

for i in range(10):
    print(f"Run {i+1}")

    grid_dt = GridSearchCV(pipe, param_grid_dt, cv=5, scoring='accuracy', n_jobs=-1)
    grid_dt.fit(x_train, y_train_cls)

    best_model_dt = grid_dt.best_estimator_
    y_pred = best_model_dt.predict(x_test)

    acc = accuracy_score(y_test_cls, y_pred)
    f1 = f1_score(y_test_cls, y_pred, average='macro')

    if hasattr(best_model_dt.named_steps['clf'], 'predict_proba'):
        y_proba = best_model_dt.predict_proba(x_test)
        labels = unique_labels(y_train_cls, y_test_cls)
        loss = log_loss(y_test_cls, y_proba, labels=labels)
    else:
        loss = None

    acc_list.append(acc)
    f1_list.append(f1)
    loss_list.append(loss if loss is not None else float('nan'))
    
    all_labels = list(np.unique(np.concatenate([y_train_cls, y_test_cls])))
    
    # 紀錄所有參數組合結果
    for i in range(len(grid_dt.cv_results_['params'])):
        params = grid_dt.cv_results_['params'][i]
        clf = DecisionTreeClassifier()
        clf.set_params(**{k.replace('clf__', ''): v for k, v in params.items()})
        clf.fit(x_train, y_train_cls)
        y_pred_i = clf.predict(x_test)
        y_prob_i = clf.predict_proba(x_test)
        acc_i = accuracy_score(y_test_cls, y_pred_i)
        f1_i = f1_score(y_test_cls, y_pred_i, average='macro')
        loss_i = log_loss(y_test_cls, y_prob_i, labels=all_labels)

        results_grid.append({
            'max_depth': params['clf__max_depth'],
            'min_samples_split': params['clf__min_samples_split'],
            'min_samples_leaf': params['clf__min_samples_leaf'],
            'criterion': params['clf__criterion'],
            'acc': acc_i,
            'loss': loss_i,
            'f1': f1_i
        })
# Out:
# Run 1
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 2
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 3
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 4
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 5
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 6
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 7
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 8
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 9
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Run 10
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:811: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(

# %%
df_results = pd.DataFrame(results_grid)
print("\n 所有參數組合結果：")
print(df_results.sort_values(by='acc', ascending=False).reset_index(drop=True))
# Out:
#  所有參數組合結果：
#      max_depth  min_samples_split  min_samples_leaf criterion       acc  \
# 0          NaN                  2                 1   entropy  0.998529
# 1         10.0                  2                 1      gini  0.998529
# 2          NaN                  2                 1      gini  0.998529
# 3          NaN                  2                 1   entropy  0.998529
# 4         10.0                  2                 1   entropy  0.998529
# ..         ...                ...               ...       ...       ...
# 715        3.0                  2                 1      gini  0.992647
# 716        3.0                  2                 1      gini  0.992647
# 717        3.0                  2                 1      gini  0.992647
# 718        3.0                  2                 1      gini  0.992647
# 719        3.0                  2                 1      gini  0.992647
#
#          loss        f1
# 0    0.053005  0.988986
# 1    0.053005  0.988986
# 2    0.053005  0.988986
# 3    0.053005  0.988986
# 4    0.053005  0.988986
# ..        ...       ...
# 715  0.075468  0.714424
# 716  0.075468  0.714424
# 717  0.075468  0.714424
# 718  0.075468  0.714424
# 719  0.075468  0.714424
#
# [720 rows x 7 columns]

# %%
best_acc_row = df_results.loc[df_results['acc'].idxmax()]
best_loss_row = df_results.loc[df_results['loss'].idxmin()]
best_f1_row = df_results.loc[df_results['f1'].idxmax()]

print("\n 最佳 Accuracy 組合：")
print(best_acc_row.to_frame().T)

print("\n 最低 Loss 組合：")
print(best_loss_row.to_frame().T)

print("\n 最高 F1 Score 組合：")
print(best_f1_row.to_frame().T)
# Out:
#  最佳 Accuracy 組合：
#    max_depth min_samples_split min_samples_leaf criterion       acc      loss  \
# 54      10.0                 2                1   entropy  0.998529  0.053005
#
#           f1
# 54  0.988986
#
#  最低 Loss 組合：
#    max_depth min_samples_split min_samples_leaf criterion       acc      loss  \
# 60      10.0                 2                4   entropy  0.997059  0.004829
#
#           f1
# 60  0.977255
#
#  最高 F1 Score 組合：
#    max_depth min_samples_split min_samples_leaf criterion       acc      loss  \
# 54      10.0                 2                1   entropy  0.998529  0.053005
#
#           f1
# 54  0.988986

# %%
plot_bar_metrics(acc_list, f1_list, loss_list, model_name="DT")
# Out:
#  DT - Detailed Results:
#  Run  Accuracy  Log Loss  F1 Macro
#    1    0.9971    0.0048    0.9773
#    2    0.9971    0.0048    0.9773
#    3    0.9971    0.0048    0.9773
#    4    0.9971    0.0048    0.9773
#    5    0.9971    0.0048    0.9773
#    6    0.9971    0.0048    0.9773
#    7    0.9971    0.0048    0.9773
#    8    0.9971    0.0048    0.9773
#    9    0.9971    0.0048    0.9773
#   10    0.9971    0.0048    0.9773
